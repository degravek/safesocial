# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import auc, precision_recall_curve
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import log_loss
from nltk.corpus import stopwords
from datetime import datetime
from scipy import sparse
import seaborn as sns
import pandas as pd
import numpy as np
import _pickle as cPickle
import emoji
import nltk
import re

import matplotlib.pyplot as mp

import warnings
warnings.filterwarnings("ignore")

from anomalyFunctions import *

def correctDate(text):
    date = text.split()
    result = datetime.strptime(date[1]+date[2]+date[-1],"%b%d%Y").strftime("%s")
    return result

#-----Read comments data-----#
name = 'delta'
nrow = 3000

comments_dir = '/Users/degravek/DataScience/SafeSocial/data/' + name + '/'
imposter_dir = '/Users/degravek/DataScience/SafeSocial/data/'

comments = pd.read_csv(comments_dir + name + '.csv', usecols=['text','created_at'])
comments['created_at'] = comments['created_at'].apply(correctDate)
comments.sort_values('created_at', ascending=False)

comments = comments[:nrow][['text']]

#-----Read imposter data-----#
imposter = pd.read_csv(imposter_dir + 'corporate_dataset.csv', usecols=['text'])

#-----Combine datasets-----#
comments.drop_duplicates('text', inplace=True)
imposter.drop_duplicates('text', inplace=True)

imposter = imposter.sample(n=comments.shape[0], replace=False, random_state=0)
imposter['target'] = 1
comments['target'] = 0

df = comments.append(imposter)
df.reset_index(drop=True, inplace=True)

# %%
df['numHash']  = df['text'].apply(numHash)
df['numEmoji'] = df['text'].apply(numEmoji)
df['ratioPunc'] = df['text'].apply(ratioPunc)
df['ratioCaps'] = df['text'].apply(ratioCaps)
df['textPro'] = df['text'].apply(processTextAnomaly)

df = df[df['textPro'] != '']

df['avgWordLen']  = df['text'].apply(avgWordLen)
df['partSpeech']  = df['textPro'].apply(partSpeech)
df['ratioStop']   = df['textPro'].apply(ratioStop)
df['ratioAtuser'] = df['textPro'].apply(ratioAtuser)

df_train, df_test = train_test_split(df, test_size=0.2, random_state=0)

y_train = df_train['target'].values
y_test = df_test['target'].values

df_train.drop('target', axis=1, inplace=True)
df_train.reset_index(drop=True, inplace=True)

df_test.drop('target', axis=1, inplace=True)
df_test.reset_index(drop=True, inplace=True)

class ItemSelector(BaseEstimator, TransformerMixin):
    def __init__(self, key):
        self.key = key

    def fit(self, x, y=None):
        return self

    def transform(self, data_dict):
        return data_dict[self.key]

# %%
param_grid = [{'tvec__ngram_range': [(1,1), (3,3), (1,3)],
                'tvec__stop_words': ['english', None],
                'tvec__max_features': [500, None],
                'tvec__use_idf': [True, False],
                'tvec__analyzer': ['word', 'char'],
                'clf__penalty': ['l1', 'l2']}]

tvec = TfidfVectorizer(strip_accents='unicode', norm=None)

pipeline = Pipeline([('DCE1', ItemSelector('textPro')), ('tvec', tvec),
                    ('clf', LogisticRegression())])

grid_cv = GridSearchCV(pipeline, param_grid, scoring='accuracy', cv=5, verbose=5)
grid_cv.fit(df_train, y_train)

print(grid_cv.best_params_)
print(grid_cv.best_score_)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.867570385818561, total=   0.1s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.8665276329509907, total=   0.1s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.867570385818561, total=   0.1s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s remaining:    0.0s
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.8759124087591241, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.9s remaining:    0.0s
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.8561001042752867, total=   0.1s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.867570385818561, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.8717413972888426, total=   0.1s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.8748696558915537, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.8790406673618353, total=   0.1s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.8613138686131386, total=   0.1s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.862356621480709, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.8383733055265902, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.8550573514077163, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.872784150156413, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.8592283628779979, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.8696558915537018, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.8519290928050052, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.8665276329509907, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.872784150156413, total=   0.1s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.8748696558915537, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.6047966631908238, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.5985401459854015, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.59436913451512, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.6037539103232534, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.6141814389989573, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.5912408759124088, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.5933263816475496, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.5849843587069864, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.5891553701772679, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.6037539103232534, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.6496350364963503, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.6538060479666319, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.6631908237747653, total=   0.8s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.6725755995828988, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.6830031282586028, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.64859228362878, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.6412930135557873, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.6631908237747653, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.6642335766423357, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.6788321167883211, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8633993743482794, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8706986444212722, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8686131386861314, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8759124087591241, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8550573514077163, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.867570385818561, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8717413972888426, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8748696558915537, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8748696558915537, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8665276329509907, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8540145985401459, total=   0.8s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8425443169968717, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8456725755995829, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8529718456725756, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8519290928050052, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.8550573514077163, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.8561001042752867, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.862356621480709, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.8613138686131386, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=500, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.8665276329509907, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.8957247132429614, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.8915537017726799, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.8988529718456726, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.8894681960375391, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.8738269030239834, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.886339937434828, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.8894681960375391, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.8915537017726799, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.8894681960375391, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.8779979144942649, total=   0.1s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.894681960375391, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.8842544316996872, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.8967674661105318, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.9092805005213764, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.8873826903023984, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.8873826903023984, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.8790406673618353, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.8832116788321168, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.8988529718456726, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.8957247132429614, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.6120959332638165, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.607924921793535, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.6100104275286757, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.6235662148070907, total=   0.8s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.635036496350365, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.5954118873826904, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.59436913451512, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.5828988529718456, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.5933263816475496, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.6047966631908238, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.6830031282586028, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.6777893639207507, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.6788321167883211, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.6976016684045881, total=   0.9s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.6913451511991658, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.6652763295099061, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.6611053180396246, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.6725755995828988, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.6861313868613139, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.6913451511991658, total=   0.4s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8842544316996872, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.9061522419186653, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8978102189781022, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8967674661105318, total=   1.5s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8852971845672576, total=   0.8s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8821689259645464, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.894681960375391, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.9019812304483837, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8894681960375391, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8852971845672576, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8884254431699687, total=   1.1s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8936392075078207, total=   1.0s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.9124087591240876, total=   1.2s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.9019812304483837, total=   1.0s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8978102189781022, total=   0.9s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.8790406673618353, total=   1.0s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.881126173096976, total=   0.9s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.8988529718456726, total=   0.9s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.8978102189781022, total=   0.9s
# [CV] clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=word, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.899895724713243, total=   0.8s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.721584984358707, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.6903023983315955, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.7142857142857143, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.7236704900938478, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=True, score=0.7122002085505735, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.7194994786235662, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.6871741397288843, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.7163712200208551, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.7257559958289885, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=english, tvec__use_idf=False, score=0.7111574556830031, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.721584984358707, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.6903023983315955, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.7142857142857143, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.7236704900938478, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.7122002085505735, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.7194994786235662, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.6871741397288843, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.7163712200208551, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.7257559958289885, total=   0.3s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.7111574556830031, total=   0.2s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8592283628779979, total=   0.9s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8456725755995829, total=   0.8s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8415015641293013, total=   1.0s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8435870698644421, total=   0.7s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8456725755995829, total=   0.9s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8696558915537018, total=   0.8s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8561001042752867, total=   0.8s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8446298227320125, total=   0.5s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8633993743482794, total=   0.6s
# [CV] clf__penalty=l1, tvec__analyzer=char, tvec__max_features=500, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# ...
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.6892596454640251, total=   0.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.7153284671532847, total=   0.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.7278415015641293, total=   0.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=True, score=0.7184567257559958, total=   0.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.7194994786235662, total=   0.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.6892596454640251, total=   0.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.7142857142857143, total=   0.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.7226277372262774, total=   0.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 1), tvec__stop_words=None, tvec__use_idf=False, score=0.7174139728884255, total=   0.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.9009384775808134, total=   0.6s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.9030239833159541, total=   0.6s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8686131386861314, total=   0.6s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8915537017726799, total=   0.6s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8873826903023984, total=   0.6s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.9165797705943691, total=   0.6s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.908237747653806, total=   0.6s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8894681960375391, total=   0.5s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.899895724713243, total=   0.5s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.9040667361835245, total=   0.5s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.9009384775808134, total=   0.5s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.9030239833159541, total=   0.6s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8686131386861314, total=   0.6s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8915537017726799, total=   0.6s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8873826903023984, total=   0.6s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.9165797705943691, total=   0.5s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.908237747653806, total=   0.5s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.8894681960375391, total=   0.5s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.899895724713243, total=   0.5s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(3, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.9040667361835245, total=   0.5s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.899895724713243, total=   1.1s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.899895724713243, total=   1.1s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.872784150156413, total=   1.1s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8905109489051095, total=   1.1s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=True, score=0.8873826903023984, total=   1.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.9113660062565172, total=   1.4s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8988529718456726, total=   1.3s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8779979144942649, total=   1.3s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8884254431699687, total=   1.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=english, tvec__use_idf=False, score=0.8915537017726799, total=   1.1s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.899895724713243, total=   1.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.899895724713243, total=   1.3s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.872784150156413, total=   1.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8905109489051095, total=   1.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=True, score=0.8873826903023984, total=   1.2s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.9113660062565172, total=   1.3s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.8988529718456726, total=   1.3s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.8779979144942649, total=   1.4s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.8884254431699687, total=   1.3s
# [CV] clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False
# [CV]  clf__penalty=l2, tvec__analyzer=char, tvec__max_features=None, tvec__ngram_range=(1, 3), tvec__stop_words=None, tvec__use_idf=False, score=0.8915537017726799, total=   1.2s
# [Parallel(n_jobs=1)]: Done 480 out of 480 | elapsed:  8.2min finished
# {'clf__penalty': 'l2', 'tvec__analyzer': 'char', 'tvec__max_features': None, 'tvec__ngram_range': (3, 3), 'tvec__stop_words': 'english', 'tvec__use_idf': False}
# 0.903649635036

# %%
tvec = TfidfVectorizer(strip_accents='unicode', analyzer='char', ngram_range=(3,3),
                       max_features=None, norm=None, stop_words='english', use_idf=False)

X_train = tvec.fit_transform(df_train['textPro'])
X_test = tvec.transform(df_test['textPro'])

param_grid = [{'alpha': 10**np.linspace(-6, -1, 20)}]
grid_cv = GridSearchCV(SGDClassifier(loss='log', penalty='l2', max_iter=1000),
                                    param_grid, scoring='neg_log_loss', cv=5, verbose=1)
grid_cv.fit(X_train, y_train)

print(grid_cv.best_params_)
print(grid_cv.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  2.9min finished
# {'alpha': 0.00078475997035146064}
# -0.236813001863

# %%
predict = grid_cv.predict(X_test)

cm = confusion_matrix(y_test, predict).T
cm = cm.astype('float')/cm.sum(axis=0)

fig, ax = mp.subplots()
sns.heatmap(cm, annot=True, cmap='Blues');
ax.set_xlabel('True Label')
ax.set_ylabel('Predicted Label')
ax.xaxis.set_label_position('top')
mp.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, grid_cv.predict_proba(X_test)[:,1])
roc_auc = roc_auc_score(y_test, predict)

mp.plot(fpr, tpr, lw=1, label='AUC = %0.2f'%(roc_auc))
mp.plot([0, 1], [0, 1], '--k', lw=0.5)
mp.xlabel('False Positive Rate')
mp.ylabel('True Positive Rate')
mp.legend(loc="lower right", frameon = True).get_frame().set_edgecolor('black')
mp.show()

# %%
precision, recall, thresholds = precision_recall_curve(y_test, grid_cv.predict_proba(X_test)[:,1])

auc(recall, precision)

mp.plot(recall, precision, lw=0.5, label='AUC = %0.2f'%(roc_auc))
mp.xlabel('recall')
mp.ylabel('precision')
mp.legend(loc="lower right", frameon = True).get_frame().set_edgecolor('black')
mp.show()

# %%
tvec
# Out:
# TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(3, 3), norm=None, preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents='unicode', sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=False,
#         vocabulary=None)

# %%
model = SGDClassifier(alpha=0.00078475997035146064, loss='log', penalty='l2', max_iter=1000)
model.fit(X_train, y_train)
# Out:
# SGDClassifier(alpha=0.0007847599703514606, average=False, class_weight=None,
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', max_iter=1000, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=None,
#        shuffle=True, tol=None, verbose=0, warm_start=False)

# %%
dest = '/Users/degravek/DataScience/SafeSocial/application/pkl_objects_8172017/delta/'

cPickle.dump(model, open(os.path.join(dest, 'model_anomaly.pkl'), 'wb'), protocol=None)
cPickle.dump(tvec, open(os.path.join(dest, 'tvec_anomaly.pkl'), 'wb'), protocol=None)

# %%
text = "Bringing you more seatback entertainment than any other airline."

dnew = pd.DataFrame([text], columns=['text'])
dnew['numHash']  = dnew['text'].apply(numHash)
dnew['numEmoji'] = dnew['text'].apply(numEmoji)
dnew['ratioPunc'] = dnew['text'].apply(ratioPunc)
dnew['ratioCaps'] = dnew['text'].apply(ratioCaps)
dnew['textPro'] = dnew['text'].apply(processTextAnomaly)

dnew = dnew[dnew['textPro'] != '']

dnew['avgWordLen']  = dnew['text'].apply(avgWordLen)
dnew['partSpeech']  = dnew['textPro'].apply(partSpeech)
dnew['ratioStop']   = dnew['textPro'].apply(ratioStop)
dnew['ratioAtuser'] = dnew['textPro'].apply(ratioAtuser)

X_train = tvec.transform(dnew['textPro'])

print(grid_cv.predict_proba(X_train))
# Out:
# [[ 0.74342185  0.25657815]]

# %%
The original classifier used all data and minimized neg_log_loss on balanced data


Very good one below: logistic regression on neg_log_loss - 0.9 (0), and 0.9 (1) accuracy
tvec = TfidfVectorizer(strip_accents='unicode', analyzer='char', token_pattern=r'\w{1,}',
                ngram_range=(3,3), max_features=None, norm=None, stop_words=None,
                use_idf=True)

cvec = CountVectorizer()
sc = StandardScaler()

val_names = df_train.drop(['text','textPro','partSpeech'], axis=1).columns

X_train_text = tvec.fit_transform(df_train['textPro'])
X_train_pos  = cvec.fit_transform(df_train['partSpeech'])
X_train_val  = sc.fit_transform(df_train[val_names].values)

X_train = sparse.hstack([X_train_text]).tocsr()
